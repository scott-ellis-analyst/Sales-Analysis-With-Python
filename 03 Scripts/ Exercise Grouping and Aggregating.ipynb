# %% [markdown]
# # 4.8: Grouping Data and Aggregating Variables

# %% [markdown]
# ## Contents:
# 1. Importing data
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ### 1. Importing data

# %%
import pandas as pd
import numpy as np
import os

# %%
# creating path for data import

path = r'C:\Users\scott\Desktop\Data Analysis\CF Immersive\Python\Jan-2022 Instacart Basket Analysis'

# %%
# importing merged orders/products dataframe

ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'orders_products_labels.pkl'))

# %%
# creating subset

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    NaN         196                  1          0   both
# 1                   15.0         196                  1          1   both
# 2                   21.0         196                  1          1   both
# 3                   29.0         196                  1          1   both
# 4                   28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices exists    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day
# 0  Regularly busy  Regularly busy        Average orders
# 1  Regularly busy    Slowest days        Average orders
# 2  Regularly busy    Slowest days           Most orders
# 3      Least busy    Slowest days        Average orders
# 4      Least busy    Slowest days           Most orders

# %%
df[df['user_id'] == 82].sort_values('order_number')
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 58       1889835       82             1                   3
# 529607   1889835       82             1                   3
# 64027    1889835       82             1                   3
# 619533   1889835       82             1                   3
# 619534    762760       82             2                   0
# 64028     762760       82             2                   0
# 529608    499460       82             3                   5
# 59        499460       82             3                   5
# 619535   2728456       82             4                   0
# 60       2728456       82             4                   0
# 64029    2728456       82             4                   0
# 538171   2728456       82             4                   0
# 529609   2728456       82             4                   0
# 453294   2728456       82             4                   0
# 453295     80629       82             5                   5
# 64030      80629       82             5                   5
# 619536     80629       82             5                   5
# 61       2653743       82             6                   4
# 619537   2232529       82             7                   1
# 64031    2232529       82             7                   1
# 538172   2232529       82             7                   1
# 538173   1358880       82             9                   1
# 453296   1358880       82             9                   1
# 62       1358880       82             9                   1
# 64032    1358880       82             9                   1
# 453297    343588       82            10                   2
# 538174    343588       82            10                   2
# 63        343588       82            10                   2
# 538175   2500881       82            11                   5
# 64033    2500881       82            11                   5
# 64034    1493222       82            12                   4
# 538176   1501349       82            13                   0
# 64035    1501349       82            13                   0
# 619538   1501349       82            13                   0
# 453298   1501349       82            13                   0
# 453299   1854627       82            14                   4
# 538177   1854627       82            14                   4
# 64036    1854627       82            14                   4
# 64037    3034663       82            15                   2
# 619539   3034663       82            15                   2
# 64       3034663       82            15                   2
# 64038    2222448       82            16                   1
# 538178   2222448       82            16                   1
# 64039     760382       82            17                   1
# 538179    760382       82            17                   1
# 453300    760382       82            17                   1
# 619540    760382       82            17                   1
# 65        147262       82            18                   1
# 538180   3144004       82            19                   2
# 64040    3144004       82            19                   2
# 66       3144004       82            19                   2
# 619541   3144004       82            19                   2
#
#         order_hour_of_day  days_since_last_order  product_id  \
# 58                     15                    NaN         196
# 529607                 15                    NaN       46149
# 64027                  15                    NaN       13176
# 619533                 15                    NaN       38928
# 619534                 11                   18.0       38928
# 64028                  11                   18.0       13176
# 529608                 10                    5.0       46149
# 59                     10                    5.0         196
# 619535                 11                   16.0       38928
# 60                     11                   16.0         196
# 64029                  11                   16.0       13176
# 538171                 11                   16.0       49235
# 529609                 11                   16.0       46149
# 453294                 11                   16.0       30450
# 453295                 16                   12.0       30450
# 64030                  16                   12.0       13176
# 619536                 16                   12.0       38928
# 61                      9                   13.0         196
# 619537                 11                   11.0       38928
# 64031                  11                   11.0       13176
# 538172                 11                   11.0       49235
# 538173                 10                   30.0       49235
# 453296                 10                   30.0       30450
# 62                     10                   30.0         196
# 64032                  10                   30.0       13176
# 453297                 11                    1.0       30450
# 538174                 11                    1.0       49235
# 63                     11                    1.0         196
# 538175                 16                   10.0       49235
# 64033                  16                   10.0       13176
# 64034                  19                    6.0       13176
# 538176                 10                   10.0       49235
# 64035                  10                   10.0       13176
# 619538                 10                   10.0       38928
# 453298                 10                   10.0       30450
# 453299                 10                   11.0       30450
# 538177                 10                   11.0       49235
# 64036                  10                   11.0       13176
# 64037                  11                   12.0       13176
# 619539                 11                   12.0       38928
# 64                     11                   12.0         196
# 64038                   8                   13.0       13176
# 538178                  8                   13.0       49235
# 64039                  12                   14.0       13176
# 538179                 12                   14.0       49235
# 453300                 12                   14.0       30450
# 619540                 12                   14.0       38928
# 65                     13                    7.0         196
# 538180                 15                    8.0       49235
# 64040                  15                    8.0       13176
# 66                     15                    8.0         196
# 619541                 15                    8.0       38928
#
#         add_to_cart_order  reordered _merge              product_name  \
# 58                      6          0   both                      Soda
# 529607                  9          0   both         Zero Calorie Cola
# 64027                   1          0   both    Bag of Organic Bananas
# 619533                  4          0   both  0% Greek Strained Yogurt
# 619534                  3          1   both  0% Greek Strained Yogurt
# 64028                   5          1   both    Bag of Organic Bananas
# 529608                  1          1   both         Zero Calorie Cola
# 59                      2          1   both                      Soda
# 619535                  2          1   both  0% Greek Strained Yogurt
# 60                      1          1   both                      Soda
# 64029                   3          1   both    Bag of Organic Bananas
# 538171                 11          0   both       Organic Half & Half
# 529609                  6          1   both         Zero Calorie Cola
# 453294                  8          0   both      Creamy Almond Butter
# 453295                  3          1   both      Creamy Almond Butter
# 64030                   6          1   both    Bag of Organic Bananas
# 619536                  5          1   both  0% Greek Strained Yogurt
# 61                      5          1   both                      Soda
# 619537                  3          1   both  0% Greek Strained Yogurt
# 64031                   4          1   both    Bag of Organic Bananas
# 538172                  5          1   both       Organic Half & Half
# 538173                  2          1   both       Organic Half & Half
# 453296                  4          1   both      Creamy Almond Butter
# 62                      1          1   both                      Soda
# 64032                   6          1   both    Bag of Organic Bananas
# 453297                  4          1   both      Creamy Almond Butter
# 538174                  2          1   both       Organic Half & Half
# 63                      1          1   both                      Soda
# 538175                  7          1   both       Organic Half & Half
# 64033                   1          1   both    Bag of Organic Bananas
# 64034                   2          1   both    Bag of Organic Bananas
# 538176                  3          1   both       Organic Half & Half
# 64035                   2          1   both    Bag of Organic Bananas
# 619538                  8          1   both  0% Greek Strained Yogurt
# 453298                 10          1   both      Creamy Almond Butter
# 453299                  7          1   both      Creamy Almond Butter
# 538177                  3          1   both       Organic Half & Half
# 64036                   2          1   both    Bag of Organic Bananas
# 64037                   4          1   both    Bag of Organic Bananas
# 619539                  7          1   both  0% Greek Strained Yogurt
# 64                      1          1   both                      Soda
# 64038                   2          1   both    Bag of Organic Bananas
# 538178                  3          1   both       Organic Half & Half
# 64039                   2          1   both    Bag of Organic Bananas
# 538179                  3          1   both       Organic Half & Half
# 453300                  6          1   both      Creamy Almond Butter
# 619540                  7          1   both  0% Greek Strained Yogurt
# 65                      1          1   both                      Soda
# 538180                  4          1   both       Organic Half & Half
# 64040                   2          1   both    Bag of Organic Bananas
# 66                      1          1   both                      Soda
# 619541                  5          1   both  0% Greek Strained Yogurt
#
#         aisle_id  department_id  prices exists    price_range_loc  \
# 58            77              7     9.0   both  Mid-range product
# 529607        77              7    13.4   both  Mid-range product
# 64027         24              4    10.3   both  Mid-range product
# 619533       120             16    12.6   both  Mid-range product
# 619534       120             16    12.6   both  Mid-range product
# 64028         24              4    10.3   both  Mid-range product
# 529608        77              7    13.4   both  Mid-range product
# 59            77              7     9.0   both  Mid-range product
# 619535       120             16    12.6   both  Mid-range product
# 60            77              7     9.0   both  Mid-range product
# 64029         24              4    10.3   both  Mid-range product
# 538171        53             16     1.8   both  Low-range product
# 529609        77              7    13.4   both  Mid-range product
# 453294        88             13     3.2   both  Low-range product
# 453295        88             13     3.2   both  Low-range product
# 64030         24              4    10.3   both  Mid-range product
# 619536       120             16    12.6   both  Mid-range product
# 61            77              7     9.0   both  Mid-range product
# 619537       120             16    12.6   both  Mid-range product
# 64031         24              4    10.3   both  Mid-range product
# 538172        53             16     1.8   both  Low-range product
# 538173        53             16     1.8   both  Low-range product
# 453296        88             13     3.2   both  Low-range product
# 62            77              7     9.0   both  Mid-range product
# 64032         24              4    10.3   both  Mid-range product
# 453297        88             13     3.2   both  Low-range product
# 538174        53             16     1.8   both  Low-range product
# 63            77              7     9.0   both  Mid-range product
# 538175        53             16     1.8   both  Low-range product
# 64033         24              4    10.3   both  Mid-range product
# 64034         24              4    10.3   both  Mid-range product
# 538176        53             16     1.8   both  Low-range product
# 64035         24              4    10.3   both  Mid-range product
# 619538       120             16    12.6   both  Mid-range product
# 453298        88             13     3.2   both  Low-range product
# 453299        88             13     3.2   both  Low-range product
# 538177        53             16     1.8   both  Low-range product
# 64036         24              4    10.3   both  Mid-range product
# 64037         24              4    10.3   both  Mid-range product
# 619539       120             16    12.6   both  Mid-range product
# 64            77              7     9.0   both  Mid-range product
# 64038         24              4    10.3   both  Mid-range product
# 538178        53             16     1.8   both  Low-range product
# 64039         24              4    10.3   both  Mid-range product
# 538179        53             16     1.8   both  Low-range product
# 453300        88             13     3.2   both  Low-range product
# 619540       120             16    12.6   both  Mid-range product
# 65            77              7     9.0   both  Mid-range product
# 538180        53             16     1.8   both  Low-range product
# 64040         24              4    10.3   both  Mid-range product
# 66            77              7     9.0   both  Mid-range product
# 619541       120             16    12.6   both  Mid-range product
#
#            busiest_day    busiest_days busiest_period_of_day
# 58      Regularly busy    Slowest days           Most orders
# 529607  Regularly busy    Slowest days           Most orders
# 64027   Regularly busy    Slowest days           Most orders
# 619533  Regularly busy    Slowest days           Most orders
# 619534     Busiest day    Busiest days           Most orders
# 64028      Busiest day    Busiest days           Most orders
# 529608  Regularly busy  Regularly busy           Most orders
# 59      Regularly busy  Regularly busy           Most orders
# 619535     Busiest day    Busiest days           Most orders
# 60         Busiest day    Busiest days           Most orders
# 64029      Busiest day    Busiest days           Most orders
# 538171     Busiest day    Busiest days           Most orders
# 529609     Busiest day    Busiest days           Most orders
# 453294     Busiest day    Busiest days           Most orders
# 453295  Regularly busy  Regularly busy           Most orders
# 64030   Regularly busy  Regularly busy           Most orders
# 619536  Regularly busy  Regularly busy           Most orders
# 61          Least busy    Slowest days           Most orders
# 619537  Regularly busy    Busiest days           Most orders
# 64031   Regularly busy    Busiest days           Most orders
# 538172  Regularly busy    Busiest days           Most orders
# 538173  Regularly busy    Busiest days           Most orders
# 453296  Regularly busy    Busiest days           Most orders
# 62      Regularly busy    Busiest days           Most orders
# 64032   Regularly busy    Busiest days           Most orders
# 453297  Regularly busy  Regularly busy           Most orders
# 538174  Regularly busy  Regularly busy           Most orders
# 63      Regularly busy  Regularly busy           Most orders
# 538175  Regularly busy  Regularly busy           Most orders
# 64033   Regularly busy  Regularly busy           Most orders
# 64034       Least busy    Slowest days        Average orders
# 538176     Busiest day    Busiest days           Most orders
# 64035      Busiest day    Busiest days           Most orders
# 619538     Busiest day    Busiest days           Most orders
# 453298     Busiest day    Busiest days           Most orders
# 453299      Least busy    Slowest days           Most orders
# 538177      Least busy    Slowest days           Most orders
# 64036       Least busy    Slowest days           Most orders
# 64037   Regularly busy  Regularly busy           Most orders
# 619539  Regularly busy  Regularly busy           Most orders
# 64      Regularly busy  Regularly busy           Most orders
# 64038   Regularly busy    Busiest days        Average orders
# 538178  Regularly busy    Busiest days        Average orders
# 64039   Regularly busy    Busiest days           Most orders
# 538179  Regularly busy    Busiest days           Most orders
# 453300  Regularly busy    Busiest days           Most orders
# 619540  Regularly busy    Busiest days           Most orders
# 65      Regularly busy    Busiest days           Most orders
# 538180  Regularly busy  Regularly busy           Most orders
# 64040   Regularly busy  Regularly busy           Most orders
# 66      Regularly busy  Regularly busy           Most orders
# 619541  Regularly busy  Regularly busy           Most orders

# %%
df['order_number'].value_counts(dropna = False)
# Out:
# 1     60085
# 2     57974
# 3     57431
# 4     50916
# 5     46258
#       ...
# 95      557
# 97      544
# 96      543
# 99      490
# 98      490
# Name: order_number, Length: 99, dtype: int64

# %%
# grouping by product_name

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id').agg({'order_number': ['mean','min','max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
# create max_order column

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    NaN         196                  1          0   both
# 1                   15.0         196                  1          1   both
# 2                   21.0         196                  1          1   both
# 3                   29.0         196                  1          1   both
# 4                   28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices exists    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day  max_order
# 0  Regularly busy  Regularly busy        Average orders         10
# 1  Regularly busy    Slowest days        Average orders         10
# 2  Regularly busy    Slowest days           Most orders         10
# 3      Least busy    Slowest days        Average orders         10
# 4      Least busy    Slowest days           Most orders         10

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id','loyalty_flag','order_number']].head(50)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
